# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
path = "C:/Users/Camila Estacuy M/OneDrive/Escritorio"
file = "LaboratorioML/operacionesmayo.csv"
pathdata = os.path.join(path,file)

# %%
data = pd.read_csv(pathdata)

# %%
metascump = data.loc[data['MetaCumplida'] == 'Yes', ["TiendasVentas"]]
metascump.head(20)
# Out:
#             TiendasVentas
# 0   Tienda Quetzaltenango
# 1           Tienda Sololá
# 2      Tienda Mazatenango
# 6           Tienda Jalapa
# 8           Tienda Zacapa
# 9          Tienda Jutiapa
# 11            Tienda Toto
# 14            Tienda Sija
# 15         Tienda Antigua

# %% [markdown]
# ######

# %%
# %matplotlib inline

# %%
dispersion = data.plot(kind="scatter", x="Ventas2020", y="TiendasVentas")
plt.title("Dispersión de Ventas en el año 2020")
# Out:
# Text(0.5, 1.0, 'Dispersión de Ventas en el año 2020')

# %%
dispersiondos = data.plot(kind="scatter", x="Ventas2021", y="TiendasVentas")
plt.title("Dispersión de Ventas en el año 2021")
# Out:
# Text(0.5, 1.0, 'Dispersión de Ventas en el año 2021')
